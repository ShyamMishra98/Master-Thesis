# %% [markdown]
# ## TensorFlow English  text summarization
#
# The system from the Natural Language Processing Lab at Tsinghua University, China is used for text summarization of three different datasets. The implementation is a TensorFlow sequence-to-sequence model using a bidirectional GRU encoder and a GRU decoder. This notebook also includes pyrouge evaluation of the test datasets.

# %%
# Google drive is mounted and the source code is saved in the Google drive

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
% cd gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %% [markdown]
# Clone the source code from the Github repository [TensorFlow-Summarization](https://github.com/thunlp/TensorFlow-Summarization.git) into your local drive

# %%
# !git clone https://github.com/thunlp/TensorFlow-Summarization.git
# Out:
# Cloning into 'TensorFlow-Summarization'...
# remote: Enumerating objects: 218, done.
# remote: Total 218 (delta 0), reused 0 (delta 0), pack-reused 218
# Receiving objects: 100% (218/218), 871.09 KiB | 11.03 MiB/s, done.
# Resolving deltas: 100% (115/115), done.

# %%
# %cd TensorFlow-Summarization
# Out:
# /content/gdrive/My Drive/Thesis/TensorFlow-Summarization

# %%
# install the tensorflow library of CPU version

# !pip3 install -U tensorflow==1.1
# Out:
# Collecting tensorflow==1.1
#   Downloading https://files.pythonhosted.org/packages/cd/e4/b2a8bcd1fa689489050386ec70c5c547e4a75d06f2cc2b55f45463cd092c/tensorflow-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (31.4MB)
#      |████████████████████████████████| 31.4MB 59.8MB/s
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.1) (0.33.4)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.10 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.1) (0.15.5)
# Requirement already satisfied, skipping upgrade: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.1) (1.12.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.1) (1.16.4)
# Requirement already satisfied, skipping upgrade: protobuf>=3.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.1) (3.7.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.2.0->tensorflow==1.1) (41.0.1)
# ERROR: stable-baselines 2.2.1 has requirement tensorflow>=1.5.0, but you'll have tensorflow 1.1.0 which is incompatible.
# ERROR: magenta 0.3.19 has requirement tensorflow>=1.12.0, but you'll have tensorflow 1.1.0 which is incompatible.
# Installing collected packages: tensorflow
#   Found existing installation: tensorflow 1.14.0
#     Uninstalling tensorflow-1.14.0:
#       Successfully uninstalled tensorflow-1.14.0
# Successfully installed tensorflow-1.1.0

# %%
# !pip3 uninstall tensorflow-gpu==1.1 # Uninstall GPU version of tensorflow if installed
# Out:
# WARNING: Skipping tensorflow-gpu as it is not installed.

# %%
import tensorflow

# %% [markdown]
# The datasets are downloaded from [here](https://github.com/harvardnlp/sent-summary) and the pretrained model is downloaded from [here](https://drive.google.com/drive/folders/1IiwyHBzK7xvUtMrRY7VHzIRJzkzXn4LM?usp=sharing).
#
# The zip file of the datasets are extracted inside the data folder and models are extracted inside the model folder. The files are arranged as shown in their Github [repository](https://github.com/thunlp/TensorFlow-Summarization.git).

# %%
# run the test script which summaries the test datasets in the data folder using pre-trained models. 
# the machine generated summaries for three datasets Gigaword, DUC 2003 and DUC 2004 are saved in the output folder.

# !python script/test.py
# Out:
# [['model', '300000']]
# Aug 09 13:12 test.py[line:49] INFO Test model/model.ckpt-300000.
# Aug 09 13:12 test.py[line:53] INFO Test data/test.giga.txt with beam_size = 1
# Aug 09 13:12 data_util.py[line:17] INFO Try load dict from data/doc_dict.txt.
# Aug 09 13:12 data_util.py[line:33] INFO Load dict data/doc_dict.txt with 30000 words.
# Aug 09 13:12 data_util.py[line:17] INFO Try load dict from data/sum_dict.txt.
# Aug 09 13:12 data_util.py[line:33] INFO Load dict data/sum_dict.txt with 30000 words.
# Aug 09 13:12 data_util.py[line:172] INFO Load test document from data/test.giga.txt.
# Aug 09 13:12 data_util.py[line:178] INFO Load 1951 testing documents.
# Aug 09 13:12 data_util.py[line:183] INFO Doc dict covers 97.70% words.
# 2019-08-09 13:12:29.697472: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2019-08-09 13:12:29.697528: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2019-08-09 13:12:29.697540: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2019-08-09 13:12:29.697554: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2019-08-09 13:12:29.697566: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# Aug 09 13:12 summarization.py[line:195] INFO Creating 1 layers of 400 units.
# Aug 09 13:12 summarization.py[line:83] INFO Reading model parameters from model/model.ckpt-300000
# INFO:tensorflow:Restoring parameters from model/model.ckpt-300000
# Aug 09 13:12 saver.py[line:1455] INFO Restoring parameters from model/model.ckpt-300000
# Aug 09 13:12 summarization.py[line:222] INFO Finish 0 samples. :: nec <UNK> to join forces
# Aug 09 13:12 summarization.py[line:222] INFO Finish 1 samples. :: sri lanka government schools
# Aug 09 13:12 summarization.py[line:222] INFO Finish 2 samples. :: police arrest protesters
# Aug 09 13:12 summarization.py[line:222] INFO Finish 3 samples. :: factory orders up #.# percent
# Aug 09 13:12 summarization.py[line:222] INFO Finish 4 samples. :: boj bank urges calm after us decision
# Aug 09 13:12 summarization.py[line:222] INFO Finish 5 samples. :: croatia serbs to meet on croatia
# Aug 09 13:12 summarization.py[line:222] INFO Finish 6 samples. :: toyota team europe world rally championship
# Aug 09 13:12 summarization.py[line:222] INFO Finish 7 samples. :: israel prepares for funeral
# Aug 09 13:12 summarization.py[line:222] INFO Finish 8 samples. :: indian pm 's promise for kashmir elections
# Aug 09 13:13 summarization.py[line:222] INFO Finish 9 samples. :: <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UN
# Aug 09 13:13 summarization.py[line:222] INFO Finish 10 samples. :: elections in trinidad and tobago
# Aug 09 13:13 summarization.py[line:222] INFO Finish 11 samples. :: jordanian crown prince pays condolences
# Aug 09 13:13 summarization.py[line:222] INFO Finish 12 samples. :: poland 's main opposition party endorses walesa
# Aug 09 13:13 summarization.py[line:222] INFO Finish 13 samples. :: rand up against dollar
# Aug 09 13:13 summarization.py[line:222] INFO Finish 14 samples. :: amnesty says torture prisoners in guinea
# Aug 09 13:13 summarization.py[line:222] INFO Finish 15 samples. :: syrian woman arrested in turkey
# Aug 09 13:13 summarization.py[line:222] INFO Finish 16 samples. :: hong kong to expand us airlines
# Aug 09 13:13 summarization.py[line:222] INFO Finish 17 samples. :: us spy spy gets suspended jail sentence
# Aug 09 13:13 summarization.py[line:222] INFO Finish 18 samples. :: davis love thinking of golf
# Aug 09 13:13 summarization.py[line:222] INFO Finish 19 samples. :: france still high after win
# Aug 09 13:13 summarization.py[line:222] INFO Finish 20 samples. :: <UNK> ## <UNK>
# Aug 09 13:13 summarization.py[line:222] INFO Finish 21 samples. :: ## dead in nigerian airways plane crash
# Aug 09 13:13 summarization.py[line:222] INFO Finish 22 samples. :: algeria presidential election final rallies
# Aug 09 13:13 summarization.py[line:222] INFO Finish 23 samples. :: unicef voices concern over children 's plight
# Aug 09 13:13 summarization.py[line:222] INFO Finish 24 samples. :: swedish soldier killed in bosnia
# Aug 09 13:13 summarization.py[line:222] INFO Finish 25 samples. :: us judge denies extradition of mexico 's former deputy attorney general
# Aug 09 13:13 summarization.py[line:222] INFO Finish 26 samples. :: jury hears jury in killings of women
# Aug 09 13:13 summarization.py[line:222] INFO Finish 27 samples. :: hoechst to invest ### million dollars in china
# Aug 09 13:13 summarization.py[line:222] INFO Finish 28 samples. :: roh 's transition
# Aug 09 13:13 summarization.py[line:222] INFO Finish 29 samples. :: man sentenced to ## years in jail
# Aug 09 13:13 summarization.py[line:222] INFO Finish 30 samples. :: clinton proposes new plan to reopen budget impasse
# Aug 09 13:13 summarization.py[line:222] INFO Finish 31 samples. :: five east timorese youths leave embassy
# Aug 09 13:13 summarization.py[line:222] INFO Finish 32 samples. :: bosnia refugees repatriation
# Aug 09 13:13 summarization.py[line:222] INFO Finish 33 samples. :: atlantis undocks from mir space station
# Aug 09 13:13 summarization.py[line:222] INFO Finish 34 samples. :: air force plane crashes in sri lanka
# Aug 09 13:13 summarization.py[line:222] INFO Finish 35 samples. :: walesa and kwasniewski cast ballots in tight contest
# Aug 09 13:13 summarization.py[line:222] INFO Finish 36 samples. :: tea scores
# Aug 09 13:13 summarization.py[line:222] INFO Finish 37 samples. :: chechen government survives bomb attack
# Aug 09 13:13 summarization.py[line:222] INFO Finish 38 samples. :: australia 's news corp to buy satellite
# Aug 09 13:13 summarization.py[line:222] INFO Finish 39 samples. :: former israeli chief of staff to be named foreign minister
# Aug 09 13:13 summarization.py[line:222] INFO Finish 40 samples. :: war criminals wo n't be allowed to hold office
# Aug 09 13:13 summarization.py[line:222] INFO Finish 41 samples. :: <UNK> credit union suffers losses
# Aug 09 13:13 summarization.py[line:222] INFO Finish 42 samples. :: nick leeson rises to become golden boy of the asian financial
# Aug 09 13:14 summarization.py[line:222] INFO Finish 43 samples. :: <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UN
# Aug 09 13:14 summarization.py[line:222] INFO Finish 44 samples. :: mahathir to relinquish party to deputy anwar
# Aug 09 13:14 summarization.py[line:222] INFO Finish 45 samples. :: bosnian croat forces torched in bosnia
# Aug 09 13:14 summarization.py[line:222] INFO Finish 46 samples. :: mugabe 's pay <UNK> to double
# Aug 09 13:14 summarization.py[line:222] INFO Finish 47 samples. :: former us defense secretary to meet
# Aug 09 13:14 summarization.py[line:222] INFO Finish 48 samples. :: salinas says he was innocent
# Aug 09 13:14 summarization.py[line:222] INFO Finish 49 samples. :: eu mediterranean neighbors meet
# Aug 09 13:14 summarization.py[line:222] INFO Finish 50 samples. :: bosnian president accuses karadzic of us troops
# Aug 09 13:14 summarization.py[line:222] INFO Finish 51 samples. :: pakistan team manager blames claims
# Aug 09 13:14 summarization.py[line:222] INFO Finish 52 samples. :: president 's affair in political fallout
# Aug 09 13:14 summarization.py[line:222] INFO Finish 53 samples. :: french rail workers strike
# Aug 09 13:14 summarization.py[line:222] INFO Finish 54 samples. :: lewis ready to offer bowe nine million dollars
# Aug 09 13:14 summarization.py[line:222] INFO Finish 55 samples. :: ramos confident of peace talks
# Aug 09 13:14 summarization.py[line:222] INFO Finish 56 samples. :: ericsson to sell <UNK>
# Aug 09 13:14 summarization.py[line:222] INFO Finish 57 samples. :: east timorese president urges unity to end violence
# Aug 09 13:14 summarization.py[line:222] INFO Finish 58 samples. :: ireland 's savers begins to benefit from savings scheme
# Aug 09 13:14 summarization.py[line:222] INFO Finish 59 samples. :: russia welcomes us move on iran nuclear program
# Aug 09 13:14 summarization.py[line:222] INFO Finish 60 samples. :: gm expects strike despite disagreement over union contracts
# Aug 09 13:14 summarization.py[line:222] INFO Finish 61 samples. :: bangladesh football fans to watch world cup
# Aug 09 13:14 summarization.py[line:222] INFO Finish 62 samples. :: india wins toss bats on opening day
# Aug 09 13:14 summarization.py[line:222] INFO Finish 63 samples. :: polling stations close in czech legislative elections
# Aug 09 13:14 summarization.py[line:222] INFO Finish 64 samples. :: indian state rewards police for killing maoist rebels
# Aug 09 13:14 summarization.py[line:222] INFO Finish 65 samples. :: un condemns attack on russian embassy employees
# Aug 09 13:14 summarization.py[line:222] INFO Finish 66 samples. :: african trade talks to focus on private sector
# Aug 09 13:14 summarization.py[line:222] INFO Finish 67 samples. :: <UNK> wins dauphine libere prologue
# Aug 09 13:14 summarization.py[line:222] INFO Finish 68 samples. :: insider trading linked to <UNK> internet firm
# Aug 09 13:14 summarization.py[line:222] INFO Finish 69 samples. :: nadal survives hewitt in french open
# Aug 09 13:14 summarization.py[line:222] INFO Finish 70 samples. :: bomb explodes outside colombo navy base
# Aug 09 13:14 summarization.py[line:222] INFO Finish 71 samples. :: serbs in kosovo
# Aug 09 13:14 summarization.py[line:222] INFO Finish 72 samples. :: mourinho says he wants to be <UNK>
# Aug 09 13:14 summarization.py[line:222] INFO Finish 73 samples. :: russia warns against nato in ex-soviet republics
# Aug 09 13:14 summarization.py[line:222] INFO Finish 74 samples. :: robben wishes to prove dutch national coach
# Aug 09 13:14 summarization.py[line:222] INFO Finish 75 samples. :: mittal steel says hostile takeover offer begins
# Aug 09 13:14 summarization.py[line:222] INFO Finish 76 samples. :: <UNK> <UNK> <UNK>
# Aug 09 13:14 summarization.py[line:222] INFO Finish 77 samples. :: world cup soccer world cup
# Aug 09 13:14 summarization.py[line:222] INFO Finish 78 samples. :: rumsfeld says killing of al-qaeda leader is significant victory
# Aug 09 13:14 summarization.py[line:222] INFO Finish 79 samples. :: crocodile farm threatens endangered species
# Aug 09 13:14 summarization.py[line:222] INFO Finish 80 samples. :: quake survivors face final straw
# Aug 09 13:14 summarization.py[line:222] INFO Finish 81 samples. :: prince philip celebrates ##th birthday
# Aug 09 13:14 summarization.py[line:222] INFO Finish 82 samples. :: federer hopes federer can play
# Aug 09 13:14 summarization.py[line:222] INFO Finish 83 samples. :: <UNK> in spain
# Aug 09 13:14 summarization.py[line:222] INFO Finish 84 samples. :: g# ministers urge energy energy costs
# Aug 09 13:14 summarization.py[line:222] INFO Finish 85 samples. :: eriksson wants to win world cup
# Aug 09 13:14 summarization.py[line:222] INFO Finish 86 samples. :: tropical depression season
# Aug 09 13:14 summarization.py[line:222] INFO Finish 87 samples. :: olmert pledges to disarm militant groups
# Aug 09 13:14 summarization.py[line:222] INFO Finish 88 samples. :: terry may need surgery
# Aug 09 13:14 summarization.py[line:222] INFO Finish 89 samples. :: <UNK> could be given boost in leipzig
# Aug 09 13:14 summarization.py[line:222] INFO Finish 90 samples. :: al-qaeda names zarqawi <UNK> to succeed zarqawi
# Aug 09 13:14 summarization.py[line:222] INFO Finish 91 samples. :: rosicky scores twice as czechs beat united states
# Aug 09 13:14 summarization.py[line:222] INFO Finish 92 samples. :: <unk> in the music
# Aug 09 13:14 summarization.py[line:222] INFO Finish 93 samples. :: credit agricole launches cash offer for <UNK> bank
# Aug 09 13:14 summarization.py[line:222] INFO Finish 94 samples. :: iraq pm visits baghdad
# Aug 09 13:14 summarization.py[line:222] INFO Finish 95 samples. :: notre dame cathedral to name after late pope
# Aug 09 13:14 summarization.py[line:222] INFO Finish 96 samples. :: somali militia chiefs flee
# Aug 09 13:14 summarization.py[line:222] INFO Finish 97 samples. :: french press in world cup opener
# Aug 09 13:14 summarization.py[line:222] INFO Finish 98 samples. :: algeria press freedom
# Aug 09 13:14 summarization.py[line:222] INFO Finish 99 samples. :: nalbandian optimistic of being fit
# Aug 09 13:14 summarization.py[line:222] INFO Finish 100 samples. :: consortium raises takeover offer of british ports
# Aug 09 13:14 summarization.py[line:222] INFO Finish 101 samples. :: beckenbauer hopes germany not <UNK> with england
# Aug 09 13:14 summarization.py[line:222] INFO Finish 102 samples. :: berlusconi re-elected as ac milan
# Aug 09 13:14 summarization.py[line:222] INFO Finish 103 samples. :: nato chief says taliban attacks in afghanistan
# Aug 09 13:14 summarization.py[line:222] INFO Finish 104 samples. :: bollywood 's top actor refuses to quit
# Aug 09 13:14 summarization.py[line:222] INFO Finish 105 samples. :: eu leaders launch new new wave of expansion
# Aug 09 13:14 summarization.py[line:222] INFO Finish 106 samples. :: mauritania 's ruling military launches electoral campaign
# Aug 09 13:14 summarization.py[line:222] INFO Finish 107 samples. :: slovaks start voting in elections
# Aug 09 13:14 summarization.py[line:222] INFO Finish 108 samples. :: mickelson mickelson still lead
# Aug 09 13:14 summarization.py[line:222] INFO Finish 109 samples. :: whaling world whaling
# Aug 09 13:14 summarization.py[line:222] INFO Finish 110 samples. :: university graduates to teach their skills
# Aug 09 13:14 summarization.py[line:222] INFO Finish 111 samples. :: world cup group g match
# Aug 09 13:14 summarization.py[line:222] INFO Finish 112 samples. :: ivory coast <UNK> in world cup group c match
# Aug 09 13:14 summarization.py[line:222] INFO Finish 113 samples. :: klinsmann says world cup is not <UNK>
# Aug 09 13:14 summarization.py[line:222] INFO Finish 114 samples. :: ukraine beats saudi arabia in world cup
# Aug 09 13:14 summarization.py[line:222] INFO Finish 115 samples. :: <UNK> on croatia
# Aug 09 13:14 summarization.py[line:222] INFO Finish 116 samples. :: sri lankan rebels reaffirm commitment to truce despite violence
# Aug 09 13:14 summarization.py[line:222] INFO Finish 117 samples. :: forest fires in state forests
# Aug 09 13:14 summarization.py[line:222] INFO Finish 118 samples. :: missile missile test system
# Aug 09 13:14 summarization.py[line:222] INFO Finish 119 samples. :: afghan journalists outraged
# Aug 09 13:14 summarization.py[line:222] INFO Finish 120 samples. :: skorea to consider nkorea food aid
# Aug 09 13:14 summarization.py[line:222] INFO Finish 121 samples. :: us lawyer to sue poland over debt repayment
# Aug 09 13:14 summarization.py[line:222] INFO Finish 122 samples. :: immigrants stage peaceful breakout
# Aug 09 13:14 summarization.py[line:222] INFO Finish 123 samples. :: south korea marching towards world cup
# Aug 09 13:14 summarization.py[line:222] INFO Finish 124 samples. :: cathay pacific orders six boeing freighter
# Aug 09 13:14 summarization.py[line:222] INFO Finish 125 samples. :: chinese scientists urge bird flu letter
# Aug 09 13:14 summarization.py[line:222] INFO Finish 126 samples. :: injury injury blow for argentina
# Aug 09 13:14 summarization.py[line:222] INFO Finish 127 samples. :: # arrested in sears tower plot
# Aug 09 13:14 summarization.py[line:222] INFO Finish 128 samples. :: blair calls for criminal justice system
# Aug 09 13:14 summarization.py[line:222] INFO Finish 129 samples. :: world cup results
# Aug 09 13:14 summarization.py[line:222] INFO Finish 130 samples. :: us says al-qaeda video is terrorist
# Aug 09 13:14 summarization.py[line:222] INFO Finish 131 samples. :: krajicek wins <UNK> tennis
# Aug 09 13:14 summarization.py[line:222] INFO Finish 132 samples. :: arcelor to meet in luxembourg
# Aug 09 13:14 summarization.py[line:222] INFO Finish 133 samples. :: man hangs himself in taiwan
# Aug 09 13:14 summarization.py[line:222] INFO Finish 134 samples. :: france beats south africa
# Aug 09 13:14 summarization.py[line:222] INFO Finish 135 samples. :: france seeks release of <UNK> <UNK>
# Aug 09 13:14 summarization.py[line:222] INFO Finish 136 samples. :: five executed for drug trafficking
# Aug 09 13:14 summarization.py[line:222] INFO Finish 137 samples. :: vote on constitutional change in italy
# Aug 09 13:14 summarization.py[line:222] INFO Finish 138 samples. :: vietnam president set to get new premier
# Aug 09 13:14 summarization.py[line:222] INFO Finish 139 samples. :: wigan moves to consolidate premiership
# Aug 09 13:14 summarization.py[line:222] INFO Finish 140 samples. :: katrina <UNK>
# Aug 09 13:14 summarization.py[line:222] INFO Finish 141 samples. :: nuclear energy deal clears first hurdle
# Aug 09 13:14 summarization.py[line:222] INFO Finish 142 samples. :: china corruption corruption
# Aug 09 13:14 summarization.py[line:222] INFO Finish 143 samples. :: rome clubs invite prince victor
# Aug 09 13:14 summarization.py[line:222] INFO Finish 144 samples. :: al-aqsa martyrs brigades
# Aug 09 13:14 summarization.py[line:222] INFO Finish 145 samples. :: kuwaiti women elect parliament for first time
# Aug 09 13:14 summarization.py[line:222] INFO Finish 146 samples. :: g# ministers meet to raise pressure on iran
# Aug 09 13:14 summarization.py[line:222] INFO Finish 147 samples. :: greece warns of violence in mideast
# Aug 09 13:14 summarization.py[line:222] INFO Finish 148 samples. :: european stocks advance on bargain-hunting
# Aug 09 13:14 summarization.py[line:222] INFO Finish 149 samples. :: australia warns of asbestos compensation
# Aug 09 13:14 summarization.py[line:222] INFO Finish 150 samples. :: palestinian pm says government is continuing
# Aug 09 13:14 summarization.py[line:222] INFO Finish 151 samples. :: bosnia bosnia serbs wanted in srebrenica massacre
# Aug 09 13:14 summarization.py[line:222] INFO Finish 152 samples. :: italy beats ukraine #-#
# Aug 09 13:14 summarization.py[line:222] INFO Finish 153 samples. :: north korea mourns kim <UNK>
# Aug 09 13:14 summarization.py[line:222] INFO Finish 154 samples. :: sydney revelers celebrate gay mardi gras
# Aug 09 13:14 summarization.py[line:222] INFO Finish 155 samples. :: mobutu to stay at french riviera residence
# Aug 09 13:14 summarization.py[line:222] INFO Finish 156 samples. :: rand weaker against dollar
# Aug 09 13:14 summarization.py[line:222] INFO Finish 157 samples. :: sunni moslem moslem authority to visit germany
# Aug 09 13:14 summarization.py[line:222] INFO Finish 158 samples. :: chirac says eu 's maastricht treaty
# Aug 09 13:14 summarization.py[line:222] INFO Finish 159 samples. :: man killed in knife fight
# Aug 09 13:14 summarization.py[line:222] INFO Finish 160 samples. :: official in official
# Aug 09 13:14 summarization.py[line:222] INFO Finish 161 samples. :: croatia protests attack against catholic church
# Aug 09 13:14 summarization.py[line:222] INFO Finish 162 samples. :: french magistrates accused of judicial misconduct
# Aug 09 13:14 summarization.py[line:222] INFO Finish 163 samples. :: germany to donate ###,### dollars in quake victims
# Aug 09 13:14 summarization.py[line:222] INFO Finish 164 samples. :: imf chief warns india to catch up
# Aug 09 13:14 summarization.py[line:222] INFO Finish 165 samples. :: canadian retail chain to pull <UNK> from canadian stores
# Aug 09 13:14 summarization.py[line:222] INFO Finish 166 samples. :: india 's congress to block tax cut
# Aug 09 13:14 summarization.py[line:222] INFO Finish 167 samples. :: refugees stranded in kenya
# Aug 09 13:14 summarization.py[line:222] INFO Finish 168 samples. :: us backs efforts to curb albania unrest
# Aug 09 13:14 summarization.py[line:222] INFO Finish 169 samples. :: rwandan massacre suspect pleads not guilty
# Aug 09 13:14 summarization.py[line:222] INFO Finish 170 samples. :: us unemployment rate dips
# Aug 09 13:14 summarization.py[line:222] INFO Finish 171 samples. :: plane crash in costa rica
# Aug 09 13:14 summarization.py[line:222] INFO Finish 172 samples. :: zairean rebels reject ceasefire
# Aug 09 13:14 summarization.py[line:222] INFO Finish 173 samples. :: south korean union threatens new strikes
# Aug 09 13:14 summarization.py[line:222] INFO Finish 174 samples. :: mubarak to ask clinton to halt settlement
# Aug 09 13:14 summarization.py[line:222] INFO Finish 175 samples. :: hong kong 's <UNK> to continue
# Aug 09 13:14 summarization.py[line:222] INFO Finish 176 samples. :: us study links relations with india
# Aug 09 13:14 summarization.py[line:222] INFO Finish 177 samples. :: diana 's motives in homeless
# Aug 09 13:14 summarization.py[line:222] INFO Finish 178 samples. :: rand firms against dollar
# Aug 09 13:14 summarization.py[line:222] INFO Finish 179 samples. :: un chief confirms key elections in croatia
# Aug 09 13:14 summarization.py[line:222] INFO Finish 180 samples. :: arab group dismisses israeli warning on peace process
# Aug 09 13:14 summarization.py[line:222] INFO Finish 181 samples. :: sesame street extends chinese version of chinese version
# Aug 09 13:14 summarization.py[line:222] INFO Finish 182 samples. :: albanian president inches closer to tirana
# Aug 09 13:14 summarization.py[line:222] INFO Finish 183 samples. :: un general assembly to adopt resolution on jerusalem housing
# Aug 09 13:14 summarization.py[line:222] INFO Finish 184 samples. :: cambodian military growing conditions for khmer rouge peace talks
# Aug 09 13:14 summarization.py[line:222] INFO Finish 185 samples. :: share prices close #.# percent lower
# Aug 09 13:15 summarization.py[line:222] INFO Finish 186 samples. :: <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UN
# Aug 09 13:15 summarization.py[line:222] INFO Finish 187 samples. :: <UNK> to reveal details of jobs
# Aug 09 13:15 summarization.py[line:222] INFO Finish 188 samples. :: chinese legislators vote against government report
# Aug 09 13:15 summarization.py[line:222] INFO Finish 189 samples. :: man shot dead in belfast
# Aug 09 13:15 summarization.py[line:222] INFO Finish 190 samples. :: ## people in ba ###
# Aug 09 13:15 summarization.py[line:222] INFO Finish 191 samples. :: strong quake shakes central western western western western regions
# Aug 09 13:15 summarization.py[line:222] INFO Finish 192 samples. :: thousands demonstrate in brussels
# Aug 09 13:15 summarization.py[line:222] INFO Finish 193 samples. :: finance ministry unlikely to sell down its
# Aug 09 13:15 summarization.py[line:222] INFO Finish 194 samples. :: truck carrying illegal immigrants crashes in spain
# Aug 09 13:15 summarization.py[line:222] INFO Finish 195 samples. :: un chief to merge
# Aug 09 13:15 summarization.py[line:222] INFO Finish 196 samples. :: flight from xiamen to north korean defector lands
# Aug 09 13:15 summarization.py[line:222] INFO Finish 197 samples. :: jakarta stocks close #.# percent lower
# Aug 09 13:15 summarization.py[line:222] INFO Finish 198 samples. :: cleric threatens holy war
# Aug 09 13:15 summarization.py[line:222] INFO Finish 199 samples. :: clinton summit to face tough showdown
# Aug 09 13:15 summarization.py[line:222] INFO Finish 200 samples. :: plane crash in caucasus
# Aug 09 13:15 summarization.py[line:222] INFO Finish 201 samples. :: security alert after religious unrest
# Aug 09 13:15 summarization.py[line:222] INFO Finish 202 samples. :: netanyahu proposes talks on palestinian territories
# Aug 09 13:15 summarization.py[line:222] INFO Finish 203 samples. :: politicians urged to vote on euthanasia bill
# Aug 09 13:15 summarization.py[line:222] INFO Finish 204 samples. :: afghan ammunition depot explosion kills ##
# Aug 09 13:15 summarization.py[line:222] INFO Finish 205 samples. :: delta to announce new aircraft purchase
# Aug 09 13:15 summarization.py[line:222] INFO Finish 206 samples. :: gore welcomes <UNK> admission
# Aug 09 13:15 summarization.py[line:222] INFO Finish 207 samples. :: kuchma threatens parliament parliament
# Aug 09 13:15 summarization.py[line:222] INFO Finish 208 samples. :: volkswagen posts higher operating profit
# Aug 09 13:15 summarization.py[line:222] INFO Finish 209 samples. :: new study suggests criminal suspects
# Aug 09 13:15 summarization.py[line:222] INFO Finish 210 samples. :: elephant to be extinct unless government launches war
# Aug 09 13:15 summarization.py[line:222] INFO Finish 211 samples. :: gore arrives in manila
# Aug 09 13:15 summarization.py[line:222] INFO Finish 212 samples. :: girl of ## cuts off ##-year-old penis
# Aug 09 13:15 summarization.py[line:222] INFO Finish 213 samples. :: <UNK> fuji <UNK>
# Aug 09 13:15 summarization.py[line:222] INFO Finish 214 samples. :: zairean president takes note of parliament
# Aug 09 13:15 summarization.py[line:222] INFO Finish 215 samples. :: clinton to meet king hussein next week
# Aug 09 13:15 summarization.py[line:222] INFO Finish 216 samples. :: cheung kong 's cheung kong expected to report strong profits
# Aug 09 13:15 summarization.py[line:222] INFO Finish 217 samples. :: nomura securities securities
# Aug 09 13:15 summarization.py[line:222] INFO Finish 218 samples. :: china 's gore signs #.# billion dollars
# Aug 09 13:15 summarization.py[line:222] INFO Finish 219 samples. :: dalai lama leads thousands in holy buddhist rite
# Aug 09 13:15 summarization.py[line:222] INFO Finish 220 samples. :: rubber prices per <UNK> per <UNK>
# Aug 09 13:15 summarization.py[line:222] INFO Finish 221 samples. :: un expert on missing persons
# Aug 09 13:15 summarization.py[line:222] INFO Finish 222 samples. :: saudi bombing suspect in deportation hearing
# Aug 09 13:15 summarization.py[line:222] INFO Finish 223 samples. :: sudan opposition kills ### soldiers
# Aug 09 13:15 summarization.py[line:222] INFO Finish 224 samples. :: malaysia denies freezing new dealings
# Aug 09 13:15 summarization.py[line:222] INFO Finish 225 samples. :: <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UNK> <UN
# Aug 09 13:15 summarization.py[line:222] INFO Finish 226 samples. :: ## people killed in fighting in kenya
# Aug 09 13:15 summarization.py[line:222] INFO Finish 227 samples. :: sudan convicted of murders and two others beheaded
# Aug 09 13:15 summarization.py[line:222] INFO Finish 228 samples. :: asean film festival opens in cambodia
# Aug 09 13:15 summarization.py[line:222] INFO Finish 229 samples. :: macedonian construction minister resigns
# Aug 09 13:15 summarization.py[line:222] INFO Finish 230 samples. :: palestinian police shoot in hebron
# Aug 09 13:15 summarization.py[line:222] INFO Finish 231 samples. :: hostage crisis talks
# Aug 09 13:15 summarization.py[line:222] INFO Finish 232 samples. :: india pakistan end four days of talks
# Aug 09 13:15 summarization.py[line:222] INFO Finish 233 samples. :: netanyahu may meet clinton
# Aug 09 13:15 summarization.py[line:222] INFO Finish 234 samples. :: putin 's party launches campaign against illegal immigration
# Aug 09 13:15 summarization.py[line:222] INFO Finish 235 samples. :: italy 's leftwing opposition to protest education
# Aug 09 13:15 summarization.py[line:222] INFO Finish 236 samples. :: mark day for right to die
# Aug 09 13:15 summarization.py[line:222] INFO Finish 237 samples. :: india ###-# at tea
# Aug 09 13:15 summarization.py[line:222] INFO Finish 238 samples. :: eu military chief warns of dr congo intervention
# Aug 09 13:15 summarization.py[line:222] INFO Finish 239 samples. :: german public bank to ask government for loan guarantees
# Aug 09 13:15 summarization.py[line:222] INFO Finish 240 samples. :: hong kong shares close up
# Aug 09 13:15 summarization.py[line:222] INFO Finish 241 samples. :: china taiwan to see economic ties
# Aug 09 13:15 summarization.py[line:222] INFO Finish 242 samples. :: un chief to mediate in congo crisis
# Aug 09 13:15 summarization.py[line:222] INFO Finish 243 samples. :: the greatest ever
# Aug 09 13:15 summarization.py[line:222] INFO Finish 244 samples. :: obama obama vote in historic election
# Aug 09 13:15 summarization.py[line:222] INFO Finish 245 samples. :: taiwan shares open lower
# Aug 09 13:15 summarization.py[line:222] INFO Finish 246 samples. :: ten french officers sue rwanda for slander
# Aug 09 13:15 summarization.py[line:222] INFO Finish 247 samples. :: historic election in historic election
# Aug 09 13:15 summarization.py[line:222] INFO Finish 248 samples. :: eurozone retailers slip less than expected
# Aug 09 13:15 summarization.py[line:222] INFO Finish 249 samples. :: rudd praises obama 's dream
# Aug 09 13:15 summarization.py[line:222] INFO Finish 250 samples. :: obama wins us presidency
# Aug 09 13:15 summarization.py[line:222] INFO Finish 251 samples. :: us restricts iran 's financial system
# Aug 09 13:15 summarization.py[line:222] INFO Finish 252 samples. :: australia coach deans
# Aug 09 13:15 summarization.py[line:222] INFO Finish 253 samples. :: austrian bank cuts #### profit forecast
# Aug 09 13:15 summarization.py[line:222] INFO Finish 254 samples. :: india ###-# in first innings
# Aug 09 13:15 summarization.py[line:222] INFO Finish 255 samples. :: chinese police attack chinese police
# Aug 09 13:16 summarization.py[line:222] INFO Finish 256 samples. :: bush warns of stimulus measures
# Aug 09 13:16 summarization.py[line:222] INFO Finish 257 samples. :: bank lending tightens up as financial markets mount
# Aug 09 13:16 summarization.py[line:222] INFO Finish 258 samples. :: five french <UNK> die in nepal
# Aug 09 13:16 summarization.py[line:222] INFO Finish 259 samples. :: higuain scores four goals as real madrid beats malaga #-#
# Aug 09 13:16 summarization.py[line:222] INFO Finish 260 samples. :: death toll from haitian school tragedy rises to ##
# Aug 09 13:16 summarization.py[line:222] INFO Finish 261 samples. :: obama vows swift action
# Aug 09 13:16 summarization.py[line:222] INFO Finish 262 samples. :: pope marks ##th anniversary of <UNK> pogrom
# Aug 09 13:16 summarization.py[line:222] INFO Finish 263 samples. :: australian fm congratulates new new zealand pm
# Aug 09 13:16 summarization.py[line:222] INFO Finish 264 samples. :: iraq cabinet to meet in baghdad
# Aug 09 13:16 summarization.py[line:222] INFO Finish 265 samples. :: syria lebanon to boost border controls
# Aug 09 13:16 summarization.py[line:222] INFO Finish 266 samples. :: hsbc profits rise despite loan <UNK>
# Aug 09 13:16 summarization.py[line:222] INFO Finish 267 samples. :: ## suspects in mafia trial
# Aug 09 13:16 summarization.py[line:222] INFO Finish 268 samples. :: defense industry badly badly badly
# Aug 09 13:16 summarization.py[line:222] INFO Finish 269 samples. :: world stocks reverse global stocks
# Aug 09 13:16 summarization.py[line:222] INFO Finish 270 samples. :: eight arrested in france 's rail network
# Aug 09 13:16 summarization.py[line:222] INFO Finish 271 samples. :: angola cup final result
# Aug 09 13:16 summarization.py[line:222] INFO Finish 272 samples. :: iraqi fm slams us raid on syria
# Aug 09 13:16 summarization.py[line:222] INFO Finish 273 samples. :: german economic growth to halt next year
# Aug 09 13:16 summarization.py[line:222] INFO Finish 274 samples. :: new zealand shares close lower
# Aug 09 13:16 summarization.py[line:222] INFO Finish 275 samples. :: juventus beats genoa #-#
# Aug 09 13:16 summarization.py[line:222] INFO Finish 276 samples. :: wall street gains in morning trade
# Aug 09 13:16 summarization.py[line:222] INFO Finish 277 samples. :: drogba under investigation for incident
# Aug 09 13:16 summarization.py[line:222] INFO Finish 278 samples. :: china to punish singers who cheating
# Aug 09 13:16 summarization.py[line:222] INFO Finish 279 samples. :: chanderpaul hits century
# Aug 09 13:16 summarization.py[line:222] INFO Finish 280 samples. :: opel asks germany for credit guarantees
# Aug 09 13:16 summarization.py[line:222] INFO Finish 281 samples. :: chinese fishing boat hijacked off somalia
# Aug 09 13:16 summarization.py[line:222] INFO Finish 282 samples. :: vietnam rejects posco steel mill
# Aug 09 13:16 summarization.py[line:222] INFO Finish 283 samples. :: french pilots vote to press ahead with strike
# Aug 09 13:16 summarization.py[line:222] INFO Finish 284 samples. :: iran favors opec oil production
# Aug 09 13:16 summarization.py[line:222] INFO Finish 285 samples. :: villarreal 's pellegrini draw #-#
# Aug 09 13:16 summarization.py[line:222] INFO Finish 286 samples. :: gulf markets plunge on economic crisis
# Aug 09 13:16 summarization.py[line:222] INFO Finish 287 samples. :: crisis as citigroup slashes jobs
# Aug 09 13:16 summarization.py[line:222] INFO Finish 288 samples. :: mediators raise concerns over karabakh
# Aug 09 13:16 summarization.py[line:222] INFO Finish 289 samples. :: india beats england #-#
# Aug 09 13:16 summarization.py[line:222] INFO Finish 290 samples. :: tibetan exiles begin meeting
# Aug 09 13:16 summarization.py[line:222] INFO Finish 291 samples. :: british pm narrows poll
# Aug 09 13:16 summarization.py[line:222] INFO Finish 292 samples. :: barclays says investors agree to amend terms of dollars
# Aug 09 13:16 summarization.py[line:222] INFO Finish 293 samples. :: chinese shares close down #.## percent
# Aug 09 13:16 summarization.py[line:222] INFO Finish 294 samples. :: beckham s career should be over england
# Aug 09 13:16 summarization.py[line:222] INFO Finish 295 samples. :: obama transition team
# Aug 09 13:16 summarization.py[line:222] INFO Finish 296 samples. :: qaeda warns obama on afghanistan
# Aug 09 13:16 summarization.py[line:222] INFO Finish 297 samples. :: germany 's economy
# Aug 09 13:16 summarization.py[line:222] INFO Finish 298 samples. :: nuclear arms to grow
# Aug 09 13:16 summarization.py[line:222] INFO Finish 299 samples. :: medvedev demands ukraine repay debt
# Aug 09 13:16 summarization.py[line:222] INFO Finish 300 samples. :: europe 's human rights commissioner slams unacceptable conditions
# Aug 09 13:16 summarization.py[line:222] INFO Finish 301 samples. :: christmas tree tree tree
# Aug 09 13:16 summarization.py[line:222] INFO Finish 302 samples. :: opposition votes to annul elections in nicaragua
# Aug 09 13:16 summarization.py[line:222] INFO Finish 303 samples. :: oil prices continue to low
# Aug 09 13:16 summarization.py[line:222] INFO Finish 304 samples. :: malaysian shares expected to remain volatile
# Aug 09 13:16 summarization.py[line:222] INFO Finish 305 samples. :: garnett scores ## points in nba rematch
# Aug 09 13:16 summarization.py[line:222] INFO Finish 306 samples. :: alleged al-qaeda mastermind in pakistan
# Aug 09 13:16 summarization.py[line:222] INFO Finish 307 samples. :: somali pirates vow to fight back
# Aug 09 13:16 summarization.py[line:222] INFO Finish 308 samples. :: australian shares open higher
# Aug 09 13:16 summarization.py[line:222] INFO Finish 309 samples. :: defoe could miss england
# Aug 09 13:16 summarization.py[line:222] INFO Finish 310 samples. :: skorea to inject up to #.# billion dollars
# Aug 09 13:16 summarization.py[line:222] INFO Finish 311 samples. :: oil prices rally on government action
# Aug 09 13:16 summarization.py[line:222] INFO Finish 312 samples. :: malaysia cuts interest rate to #.## percent
# Aug 09 13:16 summarization.py[line:222] INFO Finish 313 samples. :: standard chartered to raise #.## billion pounds
# Aug 09 13:16 summarization.py[line:222] INFO Finish 314 samples. :: lyon crush fiorentina
# Aug 09 13:16 summarization.py[line:222] INFO Finish 315 samples. :: us banking profits slide
# Aug 09 13:16 summarization.py[line:222] INFO Finish 316 samples. :: polls open for referendum on self-rule
# Aug 09 13:16 summarization.py[line:222] INFO Finish 317 samples. :: bhp billiton drops bid for rio tinto
# Aug 09 13:16 summarization.py[line:222] INFO Finish 318 samples. :: south korea posts #.# billion dollar surplus in october
# Aug 09 13:16 summarization.py[line:222] INFO Finish 319 samples. :: iraq referendum on controversial us pact
# Aug 09 13:16 summarization.py[line:222] INFO Finish 320 samples. :: violence leaves five policemen dead in afghanistan
# Aug 09 13:16 summarization.py[line:222] INFO Finish 321 samples. :: thai army chief tells protesters they must leave
# Aug 09 13:16 summarization.py[line:222] INFO Finish 322 samples. :: formosa plastics group to lend ### million us dollars
# Aug 09 13:16 summarization.py[line:222] INFO Finish 323 samples. :: writer juan <UNK> wins cervantes prize
# Aug 09 13:16 summarization.py[line:222] INFO Finish 324 samples. :: greek state-run power corporation slumps
# Aug 09 13:16 summarization.py[line:222] INFO Finish 325 samples. :: consumer business confidence slumps in november
# Aug 09 13:16 summarization.py[line:222] INFO Finish 326 samples. :: chinese shares up #.## pct
# Aug 09 13:16 summarization.py[line:222] INFO Finish 327 samples. :: celtic midfielder hartley in scottish football
# Aug 09 13:16 summarization.py[line:222] INFO Finish 328 samples. :: french plane in mumbai
# Aug 09 13:16 summarization.py[line:222] INFO Finish 329 samples. :: turkey auctions #g mobile phone licences
# Aug 09 13:16 summarization.py[line:222] INFO Finish 330 samples. :: new zealand shares rise #.## percent
# Aug 09 13:16 summarization.py[line:222] INFO Finish 331 samples. :: new zealand win
# Aug 09 13:16 summarization.py[line:222] INFO Finish 332 samples. :: un eu call for global stimulus package
# Aug 09 13:16 summarization.py[line:222] INFO Finish 333 samples. :: four policemen killed in dagestan
# Aug 09 13:16 summarization.py[line:222] INFO Finish 334 samples. :: merkel <UNK> over key congress
# Aug 09 13:16 summarization.py[line:222] INFO Finish 335 samples. :: tigers admit ## men in suicide attack
# Aug 09 13:16 summarization.py[line:222] INFO Finish 336 samples. :: eu to take china to task at un rights commission
# Aug 09 13:16 summarization.py[line:222] INFO Finish 337 samples. :: dollar at ###.##-## yen in early tokyo trading
# Aug 09 13:16 summarization.py[line:222] INFO Finish 338 samples. :: israel qatar sign trade representation offices
# Aug 09 13:16 summarization.py[line:222] INFO Finish 339 samples. :: dollar steady ahead of us jobs data
# Aug 09 13:16 summarization.py[line:222] INFO Finish 340 samples. :: us official in china
# Aug 09 13:16 summarization.py[line:222] INFO Finish 341 samples. :: britain pledges to participate in single currency
# Aug 09 13:16 summarization.py[line:222] INFO Finish 342 samples. :: police probe of ## people
# Aug 09 13:16 summarization.py[line:222] INFO Finish 343 samples. :: tiananmen massacre day alone
# Aug 09 13:16 summarization.py[line:222] INFO Finish 344 samples. :: torture torture prisoners
# Aug 09 13:16 summarization.py[line:222] INFO Finish 345 samples. :: communist lawmakers draft law on yeltsin 's ####
# Aug 09 13:16 summarization.py[line:222] INFO Finish 346 samples. :: grid positions after indonesian motorcycle gp
# Aug 09 13:16 summarization.py[line:222] INFO Finish 347 samples. :: mystery fumes in subway
# Aug 09 13:16 summarization.py[line:222] INFO Finish 348 samples. :: algerian leaders <UNK> in first half of #### elections
# Aug 09 13:16 summarization.py[line:222] INFO Finish 349 samples. :: <UNK> wins men 's ##kg weightlifting
# Aug 09 13:16 summarization.py[line:222] INFO Finish 350 samples. :: cantona keeps up in third title
# Aug 09 13:16 summarization.py[line:222] INFO Finish 351 samples. :: liberian hostages as factional fighting enters fourth day
# Aug 09 13:16 summarization.py[line:222] INFO Finish 352 samples. :: newcastle face tough
# Aug 09 13:16 summarization.py[line:222] INFO Finish 353 samples. :: islamic countries meet in sarajevo
# Aug 09 13:16 summarization.py[line:222] INFO Finish 354 samples. :: sampras wins salem hong kong open
# Aug 09 13:16 summarization.py[line:222] INFO Finish 355 samples. :: electric car market gets jump start
# Aug 09 13:16 summarization.py[line:222] INFO Finish 356 samples. :: bayern v bremen 's bundesliga
# Aug 09 13:16 summarization.py[line:222] INFO Finish 357 samples. :: china 's boat industry boom
# Aug 09 13:16 summarization.py[line:222] INFO Finish 358 samples. :: peres warns of retaliatory strikes
# Aug 09 13:16 summarization.py[line:222] INFO Finish 359 samples. :: opec president arrives in qatar
# Aug 09 13:16 summarization.py[line:222] INFO Finish 360 samples. :: black of zimbabwe ends in indian open final
# Aug 09 13:16 summarization.py[line:222] INFO Finish 361 samples. :: hariri meets mubarak for talks
# Aug 09 13:16 summarization.py[line:222] INFO Finish 362 samples. :: israeli rocket attacks in lebanon
# Aug 09 13:16 summarization.py[line:222] INFO Finish 363 samples. :: sharjah cup one-day one-day cricket scoreboard
# Aug 09 13:16 summarization.py[line:222] INFO Finish 364 samples. :: chechnya warplanes begin limited withdrawal
# Aug 09 13:16 summarization.py[line:222] INFO Finish 365 samples. :: guangzhou sets up special zone for permanent offices
# Aug 09 13:16 summarization.py[line:222] INFO Finish 366 samples. :: hariri accuses britain of supporting hezbollah
# Aug 09 13:16 summarization.py[line:222] INFO Finish 367 samples. :: opec delegation in kuwait
# Aug 09 13:16 summarization.py[line:222] INFO Finish 368 samples. :: pilots crash in colombia
# Aug 09 13:16 summarization.py[line:222] INFO Finish 369 samples. :: india qualify for sharjah cup final
# Aug 09 13:16 summarization.py[line:222] INFO Finish 370 samples. :: christopher widens consultations on ceasefire
# Aug 09 13:16 summarization.py[line:222] INFO Finish 371 samples. :: australian fm to support peace meeting
# Aug 09 13:16 summarization.py[line:222] INFO Finish 372 samples. :: ioc calls on ioc to do more
# Aug 09 13:16 summarization.py[line:222] INFO Finish 373 samples. :: bosnia 's former warring parties call back troops
# Aug 09 13:16 summarization.py[line:222] INFO Finish 374 samples. :: newcastle united to play off for title
# Aug 09 13:16 summarization.py[line:222] INFO Finish 375 samples. :: planet hollywood opens
# Aug 09 13:16 summarization.py[line:222] INFO Finish 376 samples. :: germany protests jakarta 's violence treatment
# Aug 09 13:16 summarization.py[line:222] INFO Finish 377 samples. :: <UNK> completes hat-trick at european championships
# Aug 09 13:16 summarization.py[line:222] INFO Finish 378 samples. :: four dead in train derailment
# Aug 09 13:16 summarization.py[line:222] INFO Finish 379 samples. :: bomb blast in india hotel blast
# Aug 09 13:16 summarization.py[line:222] INFO Finish 380 samples. :: chinese couple loses court case
# Aug 09 13:16 summarization.py[line:222] INFO Finish 381 samples. :: film films in the running for cannes film festival
# Aug 09 13:16 summarization.py[line:222] INFO Finish 382 samples. :: china russia to sign treaties on police cooperation
# Aug 09 13:16 summarization.py[line:222] INFO Finish 383 samples. :: israeli aircraft crashes in south lebanon
# Aug 09 13:16 summarization.py[line:222] INFO Finish 384 samples. :: clinton announces reform agency
# Aug 09 13:16 summarization.py[line:222] INFO Finish 385 samples. :: dudayev killed in secret location
# Aug 09 13:16 summarization.py[line:222] INFO Finish 386 samples. :: mclaren to be driving mclaren
# Aug 09 13:16 summarization.py[line:222] INFO Finish 387 samples. :: poll poll for india 's ruling party
# Aug 09 13:16 summarization.py[line:222] INFO Finish 388 samples. :: french foreign minister arrives in beirut
# Aug 09 13:16 summarization.py[line:222] INFO Finish 389 samples. :: foreigners in sweden may be given access to entire country
# Aug 09 13:16 summarization.py[line:222] INFO Finish 390 samples. :: hong kong shares close down #.# percent
# Aug 09 13:16 summarization.py[line:222] INFO Finish 391 samples. :: aznar to become prime minister
# Aug 09 13:16 summarization.py[line:222] INFO Finish 392 samples. :: us freezes china sanctions
# Aug 09 13:16 summarization.py[line:222] INFO Finish 393 samples. :: bayern munich win
# Aug 09 13:16 summarization.py[line:222] INFO Finish 394 samples. :: bomb explosion in kosovo
# Aug 09 13:16 summarization.py[line:222] INFO Finish 395 samples. :: gold opens lower in hong kong
# Aug 09 13:16 summarization.py[line:222] INFO Finish 396 samples. :: peres confident of lebanon ceasefire
# Aug 09 13:16 summarization.py[line:222] INFO Finish 397 samples. :: chinese pro-democracy activist arrested in shanghai
# Aug 09 13:16 summarization.py[line:222] INFO Finish 398 samples. :: ifor troops braced for violence
# Aug 09 13:16 summarization.py[line:222] INFO Finish 399 samples. :: us claims credit for ceasefire
# Aug 09 13:16 summarization.py[line:222] INFO Finish 400 samples. :: filipino boxer dies
# Aug 09 13:16 summarization.py[line:222] INFO Finish 401 samples. :: djokovic beats canas in miami masters final
# Aug 09 13:16 summarization.py[line:222] INFO Finish 402 samples. :: australian shares close down #.## percent
# Aug 09 13:16 summarization.py[line:222] INFO Finish 403 samples. :: <UNK> announces share buyback buyback buyback
# Aug 09 13:16 summarization.py[line:222] INFO Finish 404 samples. :: romney has ## million dollars in #### war chest
# Aug 09 13:16 summarization.py[line:222] INFO Finish 405 samples. :: racist abuse at rugby sevens coach
# Aug 09 13:16 summarization.py[line:222] INFO Finish 406 samples. :: qatar names pm as pm
# Aug 09 13:16 summarization.py[line:222] INFO Finish 407 samples. :: tokyo nuclear deal
# Aug 09 13:16 summarization.py[line:222] INFO Finish 408 samples. :: tendulkar breaks silence on world cup debacle
# Aug 09 13:16 summarization.py[line:222] INFO Finish 409 samples. :: israeli troops enter gaza
# Aug 09 13:16 summarization.py[line:222] INFO Finish 410 samples. :: russia wants probe of deaths of seal deaths
# Aug 09 13:16 summarization.py[line:222] INFO Finish 411 samples. :: masters <UNK>
# Aug 09 13:16 summarization.py[line:222] INFO Finish 412 samples. :: three more us soldiers killed in baghdad
# Aug 09 13:16 summarization.py[line:222] INFO Finish 413 samples. :: iraqi journalist killed in suicide bomb attack
# Aug 09 13:16 summarization.py[line:222] INFO Finish 414 samples. :: nba champs miami playoff berth
# Aug 09 13:16 summarization.py[line:222] INFO Finish 415 samples. :: roberto carlos almost destroyed in real madrid
# Aug 09 13:16 summarization.py[line:222] INFO Finish 416 samples. :: naval links with naval links
# Aug 09 13:16 summarization.py[line:222] INFO Finish 417 samples. :: pepe out for rest of season
# Aug 09 13:16 summarization.py[line:222] INFO Finish 418 samples. :: putin returns to russian orthodox patriarch
# Aug 09 13:16 summarization.py[line:222] INFO Finish 419 samples. :: us delegation arrives in north korea
# Aug 09 13:16 summarization.py[line:222] INFO Finish 420 samples. :: matsui on dl
# Aug 09 13:16 summarization.py[line:222] INFO Finish 421 samples. :: key events since overthrow of saddam hussein
# Aug 09 13:16 summarization.py[line:222] INFO Finish 422 samples. :: halliburton says it ended work commitments
# Aug 09 13:16 summarization.py[line:222] INFO Finish 423 samples. :: sarkozy brushes off remarks on le pen
# Aug 09 13:16 summarization.py[line:222] INFO Finish 424 samples. :: <UNK> to buy dutch rival <UNK> europe
# Aug 09 13:16 summarization.py[line:222] INFO Finish 425 samples. :: oil prices rebound after new supply
# Aug 09 13:16 summarization.py[line:222] INFO Finish 426 samples. :: etimor presidential election
# Aug 09 13:16 summarization.py[line:222] INFO Finish 427 samples. :: christian conservatives may have less success
# Aug 09 13:16 summarization.py[line:222] INFO Finish 428 samples. :: tom ford to open first <UNK> store in ny
# Aug 09 13:16 summarization.py[line:222] INFO Finish 429 samples. :: jet jet in london
# Aug 09 13:16 summarization.py[line:222] INFO Finish 430 samples. :: russian steel group in talks to buy <UNK>
# Aug 09 13:16 summarization.py[line:222] INFO Finish 431 samples. :: global trade growth forecast for ####
# Aug 09 13:16 summarization.py[line:222] INFO Finish 432 samples. :: un condemns algeria bombings
# Aug 09 13:16 summarization.py[line:222] INFO Finish 433 samples. :: police arrest suspects in bomb attacks
# Aug 09 13:16 summarization.py[line:222] INFO Finish 434 samples. :: world cup cricket world cup world cup
# ...
# Aug 09 14:55 summarization.py[line:222] INFO Finish 388 samples. :: report says truth commission is most comprehensive study of south african t
# Aug 09 14:55 summarization.py[line:222] INFO Finish 389 samples. :: south africa 's truth commission offers amnesty for amnesty and reconciliat
# Aug 09 14:55 summarization.py[line:222] INFO Finish 390 samples. :: death of gay student who had been tied to the fence ;
# Aug 09 14:55 summarization.py[line:222] INFO Finish 391 samples. :: death of gay student who had been tied to the fence ;
# Aug 09 14:55 summarization.py[line:222] INFO Finish 392 samples. :: gay student hospitalized in wyoming ; gay student dies in critical conditio
# Aug 09 14:55 summarization.py[line:222] INFO Finish 393 samples. :: shepard student dies at ## hours after he was left tied to
# Aug 09 14:55 summarization.py[line:222] INFO Finish 394 samples. :: shepard student dies at ## hours after he was left tied to
# Aug 09 14:55 summarization.py[line:222] INFO Finish 395 samples. :: gay college student was a press conference on the same day ago
# Aug 09 14:55 summarization.py[line:222] INFO Finish 396 samples. :: in fort collins in fort collins ; matthew shepard returns to hospital
# Aug 09 14:55 summarization.py[line:222] INFO Finish 397 samples. :: gay student mourns gay student who died in his funeral at funeral
# Aug 09 14:55 summarization.py[line:222] INFO Finish 398 samples. :: gay student mourns gay student who died in his funeral at funeral
# Aug 09 14:55 summarization.py[line:222] INFO Finish 399 samples. :: gay student mourns gay student who died in his funeral at funeral
# Aug 09 14:55 summarization.py[line:222] INFO Finish 400 samples. :: yilmaz pm under pressure to step down after allegations of corruption deal
# Aug 09 14:55 summarization.py[line:222] INFO Finish 401 samples. :: opposition parties file no-confidence motions against prime minister in ban
# Aug 09 14:55 summarization.py[line:222] INFO Finish 402 samples. :: parliament votes on whether to move government to oust government over crim
# Aug 09 14:55 summarization.py[line:222] INFO Finish 403 samples. :: former prime minister ecevit ecevit former prime minister who asked to form
# Aug 09 14:55 summarization.py[line:222] INFO Finish 404 samples. :: premier-designate says he will persist as key party leader to join forces
# Aug 09 14:55 summarization.py[line:222] INFO Finish 405 samples. :: turkish coalition partner fades as coalition partner seeks islamic party sh
# Aug 09 14:56 summarization.py[line:222] INFO Finish 406 samples. :: premier-designate says he returns to turkish president after failure to bri
# Aug 09 14:56 summarization.py[line:222] INFO Finish 407 samples. :: turkish president likely to lead government to form government after politi
# Aug 09 14:56 summarization.py[line:222] INFO Finish 408 samples. :: turkey 's premier-designate gets backing of secular parties in bid to form
# Aug 09 14:56 summarization.py[line:222] INFO Finish 409 samples. :: turkish president asks veteran left-wing politician to form new government
# Aug 09 14:56 summarization.py[line:222] INFO Finish 410 samples. :: canadians in the front lines on the streets of the front lines
# Aug 09 14:56 summarization.py[line:222] INFO Finish 411 samples. :: slaying of abortion clinic ; abortion clinic is not gone to abortion
# Aug 09 14:56 summarization.py[line:222] INFO Finish 412 samples. :: anti-abortion activist arrested in abortion clinic case ; police say he is
# Aug 09 14:56 summarization.py[line:222] INFO Finish 413 samples. :: suspect in murder of <UNK> <UNK> in u.s. custody of <UNK> <UNK>
# Aug 09 14:56 summarization.py[line:222] INFO Finish 414 samples. :: james charles is in the van riding in the front of the
# Aug 09 14:56 summarization.py[line:222] INFO Finish 415 samples. :: <UNK> <UNK> arrested in the san francisco ; police arrest ## in
# Aug 09 14:56 summarization.py[line:222] INFO Finish 416 samples. :: probe of fetus fetus linked to slaying of man who provided fetus
# Aug 09 14:56 summarization.py[line:222] INFO Finish 417 samples. :: dorothy hayes 's life is a family live in her own home
# Aug 09 14:56 summarization.py[line:222] INFO Finish 418 samples. :: new investigative unit to examine doctor 's death in wake of attack
# Aug 09 14:56 summarization.py[line:222] INFO Finish 419 samples. :: <unk> doctor knows that he knows what you were n't to know
# Aug 09 14:56 summarization.py[line:222] INFO Finish 420 samples. :: at least ## dead dozens hurt in fire in swedish dance hall
# Aug 09 14:56 summarization.py[line:222] INFO Finish 421 samples. :: fire kills ## people in sweden s second-largest city ; ## dead
# Aug 09 14:56 summarization.py[line:222] INFO Finish 422 samples. :: at least ## dead dozens hurt in fire in swedish dance hall
# Aug 09 14:56 summarization.py[line:222] INFO Finish 423 samples. :: fire kills ## people in sweden 's second-largest city ; ## people
# Aug 09 14:56 summarization.py[line:222] INFO Finish 424 samples. :: fire kills ## people in sweden 's second-largest city ; ## people
# Aug 09 14:56 summarization.py[line:222] INFO Finish 425 samples. :: fire kills ## people in sweden 's second-largest city ; ## people
# Aug 09 14:56 summarization.py[line:222] INFO Finish 426 samples. :: ## dead as fire breaks out in sweden ; ## dead ##
# Aug 09 14:56 summarization.py[line:222] INFO Finish 427 samples. :: death toll rises to ## in a day of fire that killed
# Aug 09 14:56 summarization.py[line:222] INFO Finish 428 samples. :: phone call for fire in swedish town after fire that killed ##
# Aug 09 14:56 summarization.py[line:222] INFO Finish 429 samples. :: bodies of bodies in dance hall fire still questions about ## bodies
# Aug 09 14:56 summarization.py[line:222] INFO Finish 430 samples. :: fans agree to <UNK> in return to the game for the <UNK>
# Aug 09 14:56 summarization.py[line:222] INFO Finish 431 samples. :: knoblauch 's yankee yankee stadium is a moment of truth for yankees
# Aug 09 14:56 summarization.py[line:222] INFO Finish 432 samples. :: after strawberry released from hospital ; # kids are released from hospital
# Aug 09 14:56 summarization.py[line:222] INFO Finish 433 samples. :: new york times calls for a world series of the world series
# Aug 09 14:56 summarization.py[line:222] INFO Finish 434 samples. :: yankees # yankees # in playoff game # in playoff game #
# Aug 09 14:56 summarization.py[line:222] INFO Finish 435 samples. :: yankee stadium game is n't well in the game of the game
# Aug 09 14:56 summarization.py[line:222] INFO Finish 436 samples. :: williams ready to play in game # of yankee stadium game #
# Aug 09 14:56 summarization.py[line:222] INFO Finish 437 samples. :: talk about high expectations is n't just a word on high expectations
# Aug 09 14:56 summarization.py[line:222] INFO Finish 438 samples. :: bats of bats in yanks martinez back in the game again again
# Aug 09 14:56 summarization.py[line:222] INFO Finish 439 samples. :: knoblauch and yanks are a week in a week the detroit news
# Aug 09 14:56 summarization.py[line:222] INFO Finish 440 samples. :: senate senate negotiators agree to cover contraceptives for women s birth r
# Aug 09 14:57 summarization.py[line:222] INFO Finish 441 samples. :: senate votes on <UNK> road to alaska wildlife habitat in wildlife habitat
# Aug 09 14:57 summarization.py[line:222] INFO Finish 442 samples. :: budget negotiators for congress and white house negotiators end deadline fo
# Aug 09 14:57 summarization.py[line:222] INFO Finish 443 samples. :: white house budget negotiators issue a issue of the white house budget
# Aug 09 14:57 summarization.py[line:222] INFO Finish 444 samples. :: gop white house officials spar over budget ; budget battle heats up
# Aug 09 14:57 summarization.py[line:222] INFO Finish 445 samples. :: budget battle stalls in budget battle ; gop white house officials debate
# Aug 09 14:57 summarization.py[line:222] INFO Finish 446 samples. :: budget battle stalls in budget battle ; gop white house officials debate
# Aug 09 14:57 summarization.py[line:222] INFO Finish 447 samples. :: conservatives say they 'll vote for $ ### billion on spending accord
# Aug 09 14:57 summarization.py[line:222] INFO Finish 448 samples. :: congress and white house budget spending bill budget spending bill this yea
# Aug 09 14:57 summarization.py[line:222] INFO Finish 449 samples. :: conservatives say they 'll vote for $ ### billion on spending accord
# Aug 09 14:57 summarization.py[line:222] INFO Finish 450 samples. :: yeltsin has minor burns on hand during ceremony spokesman office spokesman
# Aug 09 14:57 summarization.py[line:222] INFO Finish 451 samples. :: yeltsin doctors say he 's health more or less time less normal
# Aug 09 14:57 summarization.py[line:222] INFO Finish 452 samples. :: yeltsin cancels welcome ceremony in uzbekistan ; he feels well spokesman sa
# Aug 09 14:57 summarization.py[line:222] INFO Finish 453 samples. :: yeltsin to cut short central asian trip because of respiratory infection in
# Aug 09 14:57 summarization.py[line:222] INFO Finish 454 samples. :: yeltsin cuts short trip to central asia due to respiratory infection concer
# Aug 09 14:57 summarization.py[line:222] INFO Finish 455 samples. :: yeltsin stays home as foreign trip revives concerns about ability to govern
# Aug 09 14:57 summarization.py[line:222] INFO Finish 456 samples. :: yeltsin defies doctors orders rumors he is ill in kremlin news rumors
# Aug 09 14:57 summarization.py[line:222] INFO Finish 457 samples. :: russia 's constitutional court opens hearings on yeltsin may seek third ter
# Aug 09 14:57 summarization.py[line:222] INFO Finish 458 samples. :: russia 's constitutional court opens hearings on yeltsin may seek third ter
# Aug 09 14:57 summarization.py[line:222] INFO Finish 459 samples. :: yeltsin cancels trip to asian summit next month after illness says he
# Aug 09 14:57 summarization.py[line:222] INFO Finish 460 samples. :: silicon valley offers new opportunities in silicon valley silicon valley co
# Aug 09 14:57 summarization.py[line:222] INFO Finish 461 samples. :: judge pushes back microsoft antitrust trial to oct. ## ; judge orders
# Aug 09 14:57 summarization.py[line:222] INFO Finish 462 samples. :: microsoft to be crucial part of defense in antitrust trial next week
# Aug 09 14:57 summarization.py[line:222] INFO Finish 463 samples. :: antitrust case against microsoft in antitrust case against a century of ant
# Aug 09 14:57 summarization.py[line:222] INFO Finish 464 samples. :: antitrust case against microsoft in antitrust case against a century of ant
# Aug 09 14:57 summarization.py[line:222] INFO Finish 465 samples. :: microsoft is vague on microsoft 's antitrust antitrust data on microsoft an
# Aug 09 14:57 summarization.py[line:222] INFO Finish 466 samples. :: antitrust scrutiny of microsoft and democratic corporations and other other
# Aug 09 14:57 summarization.py[line:222] INFO Finish 467 samples. :: microsoft antitrust exec meets with silicon valley executive general justic
# Aug 09 14:57 summarization.py[line:222] INFO Finish 468 samples. :: ## sections of sherman act as federal antitrust law passed in ####
# Aug 09 14:57 summarization.py[line:222] INFO Finish 469 samples. :: microsoft s gates is n't always a nice guy gates contributed reporting
# Aug 09 14:57 summarization.py[line:222] INFO Finish 470 samples. :: police soldiers block street in front of terror suspects in front of
# Aug 09 14:57 summarization.py[line:222] INFO Finish 471 samples. :: german police raid locations near bonn embassy after threat of terrorist th
# Aug 09 14:57 summarization.py[line:222] INFO Finish 472 samples. :: islamic militant threatens to retaliate if osama bin laden arrested in saud
# Aug 09 14:57 summarization.py[line:222] INFO Finish 473 samples. :: taliban chief justice accuses us of trying to launch missile attack on
# Aug 09 14:57 summarization.py[line:222] INFO Finish 474 samples. :: fbi agents begin questioning relatives of u.s. embassy bombing victims in u
# Aug 09 14:58 summarization.py[line:222] INFO Finish 475 samples. :: suspect in u.s. embassy bombings in afghanistan declared free man in afghan
# Aug 09 14:58 summarization.py[line:222] INFO Finish 476 samples. :: new york times says state department ignored warnings of possible terrorist
# Aug 09 14:58 summarization.py[line:222] INFO Finish 477 samples. :: federal prison officials cut off for embassy bombing suspects in embassy bo
# Aug 09 14:58 summarization.py[line:222] INFO Finish 478 samples. :: osama bin laden charged with conspiring to bomb us embassies in africa
# Aug 09 14:58 summarization.py[line:222] INFO Finish 479 samples. :: judge orders review of # suspects in embassy bombing case in london
# Aug 09 14:58 summarization.py[line:222] INFO Finish 480 samples. :: lebanon army leader to be next president next president says israeli army
# Aug 09 14:58 summarization.py[line:222] INFO Finish 481 samples. :: cabinet minister criticizes choice of army commander as president to elect
# Aug 09 14:58 summarization.py[line:222] INFO Finish 482 samples. :: lebanese parliament ratifies election of army chief as president of army ch
# Aug 09 14:58 summarization.py[line:222] INFO Finish 483 samples. :: parliament elects new president as lebanon president as president as lebano
# Aug 09 14:58 summarization.py[line:222] INFO Finish 484 samples. :: parliament elects new president as lebanon president as president as lebano
# Aug 09 14:58 summarization.py[line:222] INFO Finish 485 samples. :: hariri 's bid hits snag after failing to get new president in
# Aug 09 14:58 summarization.py[line:222] INFO Finish 486 samples. :: hariri declines invite from lebanon s new president to form political crisi
# Aug 09 14:58 summarization.py[line:222] INFO Finish 487 samples. :: hariri declines invite from lebanon s new president to form political crisi
# Aug 09 14:58 summarization.py[line:222] INFO Finish 488 samples. :: prime minister says he is bowing out as premier after dispute with
# Aug 09 14:58 summarization.py[line:222] INFO Finish 489 samples. :: prime minister says he is bowing out as premier after dispute with
# Aug 09 14:58 summarization.py[line:222] INFO Finish 490 samples. :: prominent human rights campaigner as china expected to sign key human right
# Aug 09 14:58 summarization.py[line:222] INFO Finish 491 samples. :: labor rights campaigner released from us prison camp in the united states
# Aug 09 14:58 summarization.py[line:222] INFO Finish 492 samples. :: china sends dissident dissident on trial ; dissident vows to put dissident
# Aug 09 14:58 summarization.py[line:222] INFO Finish 493 samples. :: chinese courts sentenced to ## years in prison for political party party
# Aug 09 14:58 summarization.py[line:222] INFO Finish 494 samples. :: chinese fm says china 's dissident dissident unacceptable and <UNK> interna
# Aug 09 14:58 summarization.py[line:222] INFO Finish 495 samples. :: chinese fm says china 's dissident dissident unacceptable and <UNK> interna
# Aug 09 14:58 summarization.py[line:222] INFO Finish 496 samples. :: china 's dissidents signals crackdown on dissent in next year of ####
# Aug 09 14:58 summarization.py[line:222] INFO Finish 497 samples. :: political mentor jailed but <UNK> is not afraid of the political party
# Aug 09 14:58 summarization.py[line:222] INFO Finish 498 samples. :: harsh steps in crackdown on organized political opposition activists in chi
# Aug 09 14:58 summarization.py[line:222] INFO Finish 499 samples. :: chinese chinese leaders sentenced to china 's political reform china calls
# Traceback (most recent call last):
#   File "src/summarization.py", line 241, in <module>
#     tf.app.run()
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/platform/app.py", line 48, in run
#     _sys.exit(main(_sys.argv[:1] + flags_passthrough))
#   File "src/summarization.py", line 229, in main
#     decode()
#   File "src/summarization.py", line 223, in decode
#     with open(FLAGS.test_output, "w") as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'output/duc2004.10_300000.txt'

# %% [markdown]
# **Evaluation using ROUGE**
#
# Pyrouge used here for evaluation is document wise evaluation and not sentence wise.

# %%
# install pyrouge using pip

# !pip install -U git+https://github.com/pltrdy/pyrouge
# Out:
# Collecting git+https://github.com/pltrdy/pyrouge
#   Cloning https://github.com/pltrdy/pyrouge to /tmp/pip-req-build-_zoml8mq
#   Running command git clone -q https://github.com/pltrdy/pyrouge /tmp/pip-req-build-_zoml8mq
# Building wheels for collected packages: pyrouge
#   Building wheel for pyrouge (setup.py) ... done
#   Created wheel for pyrouge: filename=pyrouge-0.1.3-cp36-none-any.whl size=191883 sha256=c34d4d9b512626d71672b6084fffe37b37345cf65b6dbf8f4d925c7c64295889
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9qgzgcn4/wheels/d7/6a/52/2534a6d70b54de6e94933267ff415b0b85cdb83836af9f74c3
# Successfully built pyrouge
# Installing collected packages: pyrouge
# Successfully installed pyrouge-0.1.3

# %%
# download files2rouge code and install it

# !git clone https://github.com/pltrdy/files2rouge.git     
# %cd files2rouge
# !python setup_rouge.py
# !python setup.py install
# Out:
# Cloning into 'files2rouge'...
# remote: Enumerating objects: 202, done.
# remote: Total 202 (delta 0), reused 0 (delta 0), pack-reused 202
# Receiving objects: 100% (202/202), 195.34 KiB | 980.00 KiB/s, done.
# Resolving deltas: 100% (84/84), done.
# /content/gdrive/My Drive/Thesis/TensorFlow-Summarization/files2rouge
# files2rouge uses scripts and tools that will not be stored with the python package
# where do you want to save it? [default: /root/.files2rouge/]/content/gdrive/My Drive/Thesis/TensorFlow-Summarization/files2rouge
# Copying './files2rouge/RELEASE-1.5.5/' to '/content/gdrive/My Drive/Thesis/TensorFlow-Summarization/files2rouge'
# Traceback (most recent call last):
#   File "setup_rouge.py", line 40, in <module>
#     data = copy_rouge()
#   File "setup_rouge.py", line 33, in copy_rouge
#     shutil.copytree(src_rouge_root, path)
#   File "/usr/lib/python3.6/shutil.py", line 321, in copytree
#     os.makedirs(dst)
#   File "/usr/lib/python3.6/os.py", line 220, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '/content/gdrive/My Drive/Thesis/TensorFlow-Summarization/files2rouge'
# running install
# running bdist_egg
# running egg_info
# creating files2rouge.egg-info
# writing files2rouge.egg-info/PKG-INFO
# writing dependency_links to files2rouge.egg-info/dependency_links.txt
# writing entry points to files2rouge.egg-info/entry_points.txt
# writing top-level names to files2rouge.egg-info/top_level.txt
# writing manifest file 'files2rouge.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'files2rouge/settings.json'
# writing manifest file 'files2rouge.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/files2rouge
# copying files2rouge/__init__.py -> build/lib/files2rouge
# copying files2rouge/files2rouge.py -> build/lib/files2rouge
# copying files2rouge/settings.py -> build/lib/files2rouge
# copying files2rouge/utils.py -> build/lib/files2rouge
# creating build/lib/files2rouge/RELEASE-1.5.5
# copying files2rouge/RELEASE-1.5.5/README.txt -> build/lib/files2rouge/RELEASE-1.5.5
# copying files2rouge/RELEASE-1.5.5/RELEASE-NOTE.txt -> build/lib/files2rouge/RELEASE-1.5.5
# copying files2rouge/RELEASE-1.5.5/ROUGE-1.5.5.pl -> build/lib/files2rouge/RELEASE-1.5.5
# copying files2rouge/RELEASE-1.5.5/runROUGE-test.pl -> build/lib/files2rouge/RELEASE-1.5.5
# creating build/lib/files2rouge/RELEASE-1.5.5/XML
# copying files2rouge/RELEASE-1.5.5/XML/DOM.pm -> build/lib/files2rouge/RELEASE-1.5.5/XML
# copying files2rouge/RELEASE-1.5.5/XML/RegExp.pm -> build/lib/files2rouge/RELEASE-1.5.5/XML
# creating build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/AttDef.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/AttlistDecl.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/Attr.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/CDATASection.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/CharacterData.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/Comment.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/DOMException.pm -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/DOMImplementation.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/Document.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/DocumentFragment.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/DocumentType.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/Element.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/ElementDecl.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/Entity.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/EntityReference.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/NamedNodeMap.pm -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/NamedNodeMap.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/Node.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/NodeList.pm -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/NodeList.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/Notation.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/Parser.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/PerlSAX.pm -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/ProcessingInstruction.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/Text.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# copying files2rouge/RELEASE-1.5.5/XML/DOM/XMLDecl.pod -> build/lib/files2rouge/RELEASE-1.5.5/XML/DOM
# creating build/lib/files2rouge/RELEASE-1.5.5/XML/Handler
# copying files2rouge/RELEASE-1.5.5/XML/Handler/BuildDOM.pm -> build/lib/files2rouge/RELEASE-1.5.5/XML/Handler
# creating build/lib/files2rouge/RELEASE-1.5.5/data
# copying files2rouge/RELEASE-1.5.5/data/WordNet-2.0.exc.db -> build/lib/files2rouge/RELEASE-1.5.5/data
# copying files2rouge/RELEASE-1.5.5/data/smart_common_words.txt -> build/lib/files2rouge/RELEASE-1.5.5/data
# creating build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions
# copying files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions/adj.exc -> build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions
# copying files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions/adv.exc -> build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions
# copying files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions/buildExeptionDB.pl -> build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions
# copying files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions/noun.exc -> build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions
# copying files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions/verb.exc -> build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions
# creating build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions
# copying files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions/adj.exc -> build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions
# copying files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions/adv.exc -> build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions
# copying files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions/buildExeptionDB.pl -> build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions
# copying files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions/noun.exc -> build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions
# copying files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions/verb.exc -> build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/files2rouge
# copying build/lib/files2rouge/__init__.py -> build/bdist.linux-x86_64/egg/files2rouge
# copying build/lib/files2rouge/files2rouge.py -> build/bdist.linux-x86_64/egg/files2rouge
# copying build/lib/files2rouge/settings.py -> build/bdist.linux-x86_64/egg/files2rouge
# copying build/lib/files2rouge/utils.py -> build/bdist.linux-x86_64/egg/files2rouge
# creating build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5
# copying build/lib/files2rouge/RELEASE-1.5.5/README.txt -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5
# copying build/lib/files2rouge/RELEASE-1.5.5/RELEASE-NOTE.txt -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5
# copying build/lib/files2rouge/RELEASE-1.5.5/ROUGE-1.5.5.pl -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5
# copying build/lib/files2rouge/RELEASE-1.5.5/runROUGE-test.pl -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5
# creating build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM.pm -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/RegExp.pm -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML
# creating build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/AttDef.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/AttlistDecl.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/Attr.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/CDATASection.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/CharacterData.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/Comment.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/DOMException.pm -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/DOMImplementation.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/Document.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/DocumentFragment.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/DocumentType.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/Element.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/ElementDecl.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/Entity.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/EntityReference.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/NamedNodeMap.pm -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/NamedNodeMap.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/Node.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/NodeList.pm -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/NodeList.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/Notation.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/Parser.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/PerlSAX.pm -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/ProcessingInstruction.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/Text.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/DOM/XMLDecl.pod -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/DOM
# creating build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/Handler
# copying build/lib/files2rouge/RELEASE-1.5.5/XML/Handler/BuildDOM.pm -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/XML/Handler
# creating build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data
# copying build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-2.0.exc.db -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data
# copying build/lib/files2rouge/RELEASE-1.5.5/data/smart_common_words.txt -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data
# creating build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions
# copying build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions/adj.exc -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions
# copying build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions/adv.exc -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions
# copying build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions/buildExeptionDB.pl -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions
# copying build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions/noun.exc -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions
# copying build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions/verb.exc -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data/WordNet-1.6-Exceptions
# creating build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions
# copying build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions/adj.exc -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions
# copying build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions/adv.exc -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions
# copying build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions/buildExeptionDB.pl -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions
# copying build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions/noun.exc -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions
# copying build/lib/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions/verb.exc -> build/bdist.linux-x86_64/egg/files2rouge/RELEASE-1.5.5/data/WordNet-2.0-Exceptions
# byte-compiling build/bdist.linux-x86_64/egg/files2rouge/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/files2rouge/files2rouge.py to files2rouge.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/files2rouge/settings.py to settings.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/files2rouge/utils.py to utils.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying files2rouge.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying files2rouge.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying files2rouge.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying files2rouge.egg-info/entry_points.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying files2rouge.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# files2rouge.__pycache__.settings.cpython-36: module references __file__
# creating dist
# creating 'dist/files2rouge-2.0.0-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing files2rouge-2.0.0-py3.6.egg
# creating /usr/local/lib/python3.6/dist-packages/files2rouge-2.0.0-py3.6.egg
# Extracting files2rouge-2.0.0-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding files2rouge 2.0.0 to easy-install.pth file
# Installing files2rouge script to /usr/local/bin
#
# Installed /usr/local/lib/python3.6/dist-packages/files2rouge-2.0.0-py3.6.egg
# Processing dependencies for files2rouge==2.0.0
# Finished processing dependencies for files2rouge==2.0.0

# %%
# Evaluation duc2003

! files2rouge ../output/duc2003.10_300000.txt ../data/task1_ref0_duc2003.txt #--verbose
# Out:
# Preparing documents...
# Running ROUGE...
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.25589 (95%-conf.int. 0.24063 - 0.27148)
# 1 ROUGE-1 Average_P: 0.27932 (95%-conf.int. 0.26346 - 0.29460)
# 1 ROUGE-1 Average_F: 0.26012 (95%-conf.int. 0.24529 - 0.27475)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.08260 (95%-conf.int. 0.07293 - 0.09203)
# 1 ROUGE-2 Average_P: 0.09443 (95%-conf.int. 0.08331 - 0.10499)
# 1 ROUGE-2 Average_F: 0.08663 (95%-conf.int. 0.07662 - 0.09651)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.23126 (95%-conf.int. 0.21694 - 0.24600)
# 1 ROUGE-L Average_P: 0.25173 (95%-conf.int. 0.23722 - 0.26633)
# 1 ROUGE-L Average_F: 0.23430 (95%-conf.int. 0.22075 - 0.24771)
#
# Elapsed time: 5.567 seconds

# %%
# Evaluation duc2004

! files2rouge ../output/duc2004.10_300000.txt ../data/task1_ref0_duc2004.txt #--verbose
# Out:
# Preparing documents...
# Running ROUGE...
# ---------------------------------------------
# 1 ROUGE-1 Average_R: 0.27251 (95%-conf.int. 0.25767 - 0.28864)
# 1 ROUGE-1 Average_P: 0.29057 (95%-conf.int. 0.27528 - 0.30775)
# 1 ROUGE-1 Average_F: 0.27619 (95%-conf.int. 0.26169 - 0.29189)
# ---------------------------------------------
# 1 ROUGE-2 Average_R: 0.09100 (95%-conf.int. 0.08003 - 0.10155)
# 1 ROUGE-2 Average_P: 0.09839 (95%-conf.int. 0.08678 - 0.10993)
# 1 ROUGE-2 Average_F: 0.09251 (95%-conf.int. 0.08187 - 0.10312)
# ---------------------------------------------
# 1 ROUGE-L Average_R: 0.23900 (95%-conf.int. 0.22509 - 0.25470)
# 1 ROUGE-L Average_P: 0.25367 (95%-conf.int. 0.23872 - 0.26959)
# 1 ROUGE-L Average_F: 0.24145 (95%-conf.int. 0.22769 - 0.25601)
#
# Elapsed time: 3.122 seconds
